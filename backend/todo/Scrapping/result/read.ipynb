# %%
import pandas as pd
import numpy as np

df = pd.read_csv('kijijiauto.csv')

# %%
empty_detect = ['']
df['year'].replace(empty_detect, np.nan, inplace=True)

# %%
df.drop(columns=['Unnamed: 0.1','Unnamed: 0'], inplace=True)

# %%
df_cleaned = df.dropna(subset=['year'])
df_cleaned.reset_index(drop=True, inplace=True)

# %%
df_cleaned['year'] = df_cleaned['year'].astype(int)
# Out:
# C:\Users\Administrator\AppData\Local\Temp\2\ipykernel_5804\2559729862.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_cleaned['year'] = df_cleaned['year'].astype(int)

# %%
df_cleaned.to_csv('kijijiauto.csv', index=False)

# %%
df_cleaned.head(10)
# Out:
#        source     make                 model  year  price  mileage  \
# 0  kijijiauto      NaN  Mercedes-AMG C-Class  2019  52998    78107
# 1  kijijiauto      RAM                   NaN  2019  31495    70828
# 2  kijijiauto    Honda                 Civic  2022  33995    21460
# 3  kijijiauto   Toyota                 Camry  2018  25880    30149
# 4  kijijiauto      BMW                    X1  2018  27888    68535
# 5  kijijiauto  Hyundai              Santa Fe  2019  21995    56556
# 6  kijijiauto     Ford                   NaN  2020  29900   156000
# 7  kijijiauto   Toyota                   NaN  2021  29995    70050
# 8  kijijiauto    Honda                Accord  2017  26480   103205
# 9  kijijiauto    Lexus                    NX  2020  32995   112542
#
#           location listing_date                            link_to_buyer  \
# 0  Scarborough, ON   2024-03-11  https://www.kijijiautos.ca/vip/30873446
# 1  Mississauga, ON   2024-03-11  https://www.kijijiautos.ca/vip/30890786
# 2       Barrie, ON   2024-03-11  https://www.kijijiautos.ca/vip/29209684
# 3  Scarborough, ON   2024-03-11  https://www.kijijiautos.ca/vip/30367370
# 4   North York, ON   2024-03-11  https://www.kijijiautos.ca/vip/30056317
# 5      Toronto, ON   2024-03-11  https://www.kijijiautos.ca/vip/28024330
# 6      Toronto, ON   2024-03-11  https://www.kijijiautos.ca/vip/29796706
# 7      Toronto, ON   2024-03-11  https://www.kijijiautos.ca/vip/30101257
# 8     Oakville, ON   2024-03-11  https://www.kijijiautos.ca/vip/30392257
# 9     Oakville, ON   2024-03-11  https://www.kijijiautos.ca/vip/30023622
#
#                                        link_to_image
# 0  https://media.kijiji.ca/api/v1/autos-prod-ads/...
# 1  https://media.kijiji.ca/api/v1/autos-prod-ads/...
# 2  https://media.kijiji.ca/api/v1/autos-prod-ads/...
# 3  https://media.kijiji.ca/api/v1/autos-prod-ads/...
# 4  https://media.kijiji.ca/api/v1/autos-prod-ads/...
# 5  https://media.kijiji.ca/api/v1/autos-prod-ads/...
# 6  https://media.kijiji.ca/api/v1/autos-prod-ads/...
# 7  https://media.kijiji.ca/api/v1/autos-prod-ads/...
# 8  https://media.kijiji.ca/api/v1/autos-prod-ads/...
# 9  https://media.kijiji.ca/api/v1/autos-prod-ads/...
